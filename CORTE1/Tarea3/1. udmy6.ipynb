# %% [markdown]
# Este bloque de código importa la librería pandas, lee un archivo Excel llamado 'Nba Teams.xlsx' en un DataFrame llamado nba, y luego muestra las primeras 5 filas de ese DataFrame.

# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1024/680567536.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 nba = pd.read_excel("Nba Teams.xlsx")
#       3 nba.head()
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# Este bloque de código selecciona y muestra solo las columnas 'Name' y 'Team' del DataFrame nba.

# %%
nba[["Name", "Team"]]

# %% [markdown]
# Este bloque de código selecciona y muestra las columnas 'Name', 'Team' y 'Salary' del DataFrame nba.

# %%
nba[["Name", "Team", "Salary"]]
