# %%
#sensors = {"living room": 21, "kitchen": 23, "bedroom": 20, "pantry": 22}  # Diccionario con la temperatura registrada en cada habitación
#num_cameras = {"backyard": 6,  "garage": 2, "driveway": 1}  # Diccionario con la cantidad de cámaras instaladas en cada zona

#print(sensors)  # Muestra en consola todo el contenido de sensors
#print(num_cameras)  # Muestra en consola todo el contenido de num_cameras

#translations = {"mountain": "orod", "bread": "bass", "friend": "mellon", "horse": "roch"}  # Diccionario que asocia cada palabra en inglés con su equivalente en el idioma inventado
#print(translations)  # Muestra en consola el diccionario translations

#Verifiying an error:
# powers = {[1, 2, 4, 8, 16]: 2, [1, 3, 9, 27, 81]: 3}  # Provocaría TypeError: las listas son mutables y no pueden usarse como clave, solo como valor
# print(powers)  # Nunca llega a ejecutarse porque la línea anterior detiene el programa con el error

#children = {"von Trapp": ["Johannes", "Rosmarie", "Eleonore"], "Corleone": ["Sonny", "Fredo", "Michael"]}  # Diccionario donde cada apellido es clave y su valor es una lista de nombres
#print(children)  # Muestra en consola el diccionario children

#my_empty_dictionary = {}  # Crea un diccionario sin ningún par clave:valor
#print(my_empty_dictionary)  # Muestra en consola las llaves vacías {}

#menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}  # Diccionario con productos y su precio
#print("Before: ", menu)  # Muestra el estado del menú antes de modificarlo
#menu["cheesecake"] = 8  # Como "cheesecake" no existe aún, se agrega como clave nueva con valor 8
#print("After", menu)  # Muestra el menú ya con la clave "cheesecake" incluida

#animals_in_zoo = {"dinosaurs": 0}  # Primera asignación de la variable a un diccionario
#animals_in_zoo = {"dinosaurs": 0}  # Reasigna la variable a un diccionario idéntico al anterior
#animals_in_zoo = {"horses": 2}  # Reasigna la variable a un diccionario distinto, descartando por completo el anterior
#print(animals_in_zoo)  # Solo imprime {"horses": 2}, ya que es lo único que la variable conserva


##Add multiple keys
#sensors = {"living room": 21, "kitchen": 23, "bedroom": 20}  # Redefine sensors con solo tres habitaciones
#print("Before", sensors)  # Muestra sensors antes de agregarle más claves

#If we wanted to add 3 new rooms, we could use:
#sensors.update({"pantry": 22, "guest room": 25, "patio": 34})  # Agrega tres claves nuevas al diccionario en una sola instrucción
#print("After", sensors)  # Muestra sensors ya con las seis habitaciones

###
#user_ids = {"teraCoder": 9018293, "proProgrammer": 119238}  # Diccionario con nombres de usuario como clave y su ID como valor
#print(user_ids)  # Muestra user_ids antes de la actualización
#user_ids.update({"theLooper": 138475, "stringQueen": 85739})  # Incorpora dos usuarios nuevos al diccionario existente
#print(user_ids)  # Muestra user_ids con los cuatro usuarios ya cargados

## Overwrite Values ##
#We know that we can add a key by using the following syntax:
#menu["banana"] = 3  # Si "banana" no existe la crea con valor 3; si ya existe, reemplaza su valor actual por 3
#menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}  # Vuelve a crear el diccionario menu desde cero
#print("Before: ", menu)  # Muestra menu antes de sobrescribir un valor
#menu["oatmeal"] = 5  # Como "oatmeal" ya existe, esto reemplaza su valor (pasa de 3 a 5)
#print("After", menu)  # Muestra menu con el valor de oatmeal ya actualizado

## Notice the value of "oatmeal" has now changed to 5.
#oscar_winners = {"Best Picture": "La La Land", "Best Actor": "Casey Affleck", "Best Actress": "Emma Stone", "Animated Feature": "Zootopia"}  # Diccionario con categoría de premio como clave y ganador como valor
#print("Before", oscar_winners)  # Muestra oscar_winners en su estado original
#print()  # Deja una línea en blanco para separar la salida
#oscar_winners.update({"Supporting Actress": "Viola Davis"})  # Agrega una categoría nueva que no existía
#print("After1", oscar_winners)  # Muestra oscar_winners tras agregar la nueva categoría
#print()  # Deja otra línea en blanco
#oscar_winners["Best Picture"] = "Moonlight"  # Sobrescribe el valor de una clave que ya existía
#print("After2", oscar_winners)  # Muestra oscar_winners con la segunda modificación aplicada


###Dict Comprehensions
#Let’s say we have two lists that we want to combine into a
#dictionary, like a list of students and a list of their heights,
#in inches:

names = ['Jenny', 'Alexus', 'Sam', 'Grace']  # Lista con los nombres de los estudiantes
heights = [61, 70, 67, 64]  # Lista con la altura de cada estudiante, en el mismo orden que names

#Python allows you to create a dictionary using
# a dict comprehension, with this syntax:

#zipStudents = zip(names, heights)  # Empareja cada nombre con la altura que ocupa su misma posición
#print("zipStudents: ", zipStudents)  # No imprime los pares, sino la dirección de memoria del objeto zip (es un iterador perezoso)

#students = {key:value for key, value in zip(names, heights)}  # Recorre los pares del zip y arma el diccionario nombre:altura
#students is now {'Jenny': 61, 'Alexus': 70, 'Sam': 67, 'Grace': 64}  # Así queda el diccionario resultante
#print(students)  # Muestra el diccionario students ya construido

#zip() combines two lists into an iterator of tuples with the list elements paired together. This dict comprehension:

#drinks = ["espresso", "chai", "decaf", "drip"]  # Lista con los nombres de las bebidas
#caffeine = [64, 40, 0, 120]  # Lista con los miligramos de cafeína de cada bebida, en el mismo orden

#zipped_drinks = zip(drinks, caffeine)  # Empareja cada bebida con su cantidad de cafeína correspondiente
#print(zipped_drinks)  # Imprime la referencia en memoria del objeto zip, no su contenido

#drinks_to_caffeine = {key:value for key, value in zipped_drinks}  # Convierte los pares del zip en un diccionario bebida:cafeína
#print(drinks_to_caffeine)  # Muestra el diccionario drinks_to_caffeine ya armado

songs = ["Like a Rolling Stone", "Satisfaction", "Imagine", "What's Going On", "Respect", "Good Vibrations"]  # Lista con los títulos de las canciones
playcounts = [78, 29, 44, 21, 89, 5]  # Lista con el número de reproducciones de cada canción, en el mismo orden que songs
plays = {key:value for key, value in zip(songs, playcounts)}  # Combina ambas listas en un diccionario canción:reproducciones
print(plays)  # Muestra el diccionario plays recién creado
plays.update({"Purple Haze": 1})  # Agrega una canción que no estaba en la lista original, con 1 reproducción
plays.update({"Respect": 94})  # Sobrescribe el valor de "Respect", que ya existía, actualizándolo a 94
print("After: ", plays)  # Muestra plays con ambas modificaciones ya aplicadas
library = {"The Best Songs": plays, "Sunday Feelings": {}}  # Diccionario anidado: "The Best Songs" guarda el diccionario plays y "Sunday Feelings" queda vacío
print(library)  # Muestra el diccionario library completo, incluyendo el diccionario anidado
# Out:
# {'von Trapp': ['Johannes', 'Rosmarie', 'Eleonore'], 'Corleone': ['Sonny', 'Fredo', 'Michael']}
# {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 89, 'Good Vibrations': 5}
# After:  {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 94, 'Good Vibrations': 5, 'Purple Haze': 1}
# {'The Best Songs': {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 94, 'Good Vibrations': 5, 'Purple Haze': 1}, 'Sunday Feelings': {}}

# %%
songs = ["Like a Rolling Stone", "Satisfaction", "Imagine", "What's Going On", "Respect", "Good Vibrations"]  # Lista con los títulos de las canciones
playcounts = [78, 29, 44, 21, 89, 5]  # Lista con el número de reproducciones de cada canción, en el mismo orden que songs
plays = {key:value for key, value in zip(songs, playcounts)}  # Combina ambas listas en un diccionario canción:reproducciones
print(plays)  # Muestra el diccionario plays recién creado
plays.update({"Purple Haze": 1})  # Agrega una canción que no estaba en la lista original, con 1 reproducción
plays.update({"Respect": 94})  # Sobrescribe el valor de "Respect", que ya existía, actualizándolo a 94
print("After: ", plays)  # Muestra plays con ambas modificaciones ya aplicadas
library = {"The Best Songs": plays, "Sunday Feelings": {}}  # Diccionario anidado: "The Best Songs" guarda el diccionario plays y "Sunday Feelings" queda vacío
print(library)  # Muestra el diccionario library completo, incluyendo el diccionario anidado
# Out:
# {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 89, 'Good Vibrations': 5}
# After:  {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 94, 'Good Vibrations': 5, 'Purple Haze': 1}
# {'The Best Songs': {'Like a Rolling Stone': 78, 'Satisfaction': 29, 'Imagine': 44, "What's Going On": 21, 'Respect': 94, 'Good Vibrations': 5, 'Purple Haze': 1}, 'Sunday Feelings': {}}

# %%
#drinks_to_caffeine = {key:value for key, value in zipped_drinks}  # Convierte los pares del zip en un diccionario bebida:cafeína
#print(drinks_to_caffeine)  # Muestra el diccionario drinks_to_caffeine ya armado

# %%
#zipped_drinks = zip(drinks, caffeine)  # Empareja cada bebida con su cantidad de cafeína correspondiente
#print(zipped_drinks)  # Imprime la referencia en memoria del objeto zip, no su contenido

# %%
#zip() combines two lists into an iterator of tuples with the list elements paired together. This dict comprehension:

#drinks = ["espresso", "chai", "decaf", "drip"]  # Lista con los nombres de las bebidas
#caffeine = [64, 40, 0, 120]  # Lista con los miligramos de cafeína de cada bebida, en el mismo orden

# %%
#students = {key:value for key, value in zip(names, heights)}  # Recorre los pares del zip y arma el diccionario nombre:altura
#students is now {'Jenny': 61, 'Alexus': 70, 'Sam': 67, 'Grace': 64}  # Así queda el diccionario resultante
#print(students)  # Muestra el diccionario students ya construido

# %%
#zipStudents = zip(names, heights)  # Empareja cada nombre con la altura que ocupa su misma posición
#print("zipStudents: ", zipStudents)  # No imprime los pares, sino la dirección de memoria del objeto zip (es un iterador perezoso)

# %%
#Python allows you to create a dictionary using
# a dict comprehension, with this syntax:

# %%
names = ['Jenny', 'Alexus', 'Sam', 'Grace']  # Lista con los nombres de los estudiantes
heights = [61, 70, 67, 64]  # Lista con la altura de cada estudiante, en el mismo orden que names

# %%
###Dict Comprehensions
#Let’s say we have two lists that we want to combine into a
#dictionary, like a list of students and a list of their heights,
#in inches:

# %%
## Notice the value of "oatmeal" has now changed to 5.
#oscar_winners = {"Best Picture": "La La Land", "Best Actor": "Casey Affleck", "Best Actress": "Emma Stone", "Animated Feature": "Zootopia"}  # Diccionario con categoría de premio como clave y ganador como valor
#print("Before", oscar_winners)  # Muestra oscar_winners en su estado original
#print()  # Deja una línea en blanco para separar la salida
#oscar_winners.update({"Supporting Actress": "Viola Davis"})  # Agrega una categoría nueva que no existía
#print("After1", oscar_winners)  # Muestra oscar_winners tras agregar la nueva categoría
#print()  # Deja otra línea en blanco
#oscar_winners["Best Picture"] = "Moonlight"  # Sobrescribe el valor de una clave que ya existía
#print("After2", oscar_winners)  # Muestra oscar_winners con la segunda modificación aplicada

# %%
## Overwrite Values ##
#We know that we can add a key by using the following syntax:
#menu["banana"] = 3  # Si "banana" no existe la crea con valor 3; si ya existe, reemplaza su valor actual por 3
#menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}  # Vuelve a crear el diccionario menu desde cero
#print("Before: ", menu)  # Muestra menu antes de sobrescribir un valor
#menu["oatmeal"] = 5  # Como "oatmeal" ya existe, esto reemplaza su valor (pasa de 3 a 5)
#print("After", menu)  # Muestra menu con el valor de oatmeal ya actualizado

# %%
###
#user_ids = {"teraCoder": 9018293, "proProgrammer": 119238}  # Diccionario con nombres de usuario como clave y su ID como valor
#print(user_ids)  # Muestra user_ids antes de la actualización
#user_ids.update({"theLooper": 138475, "stringQueen": 85739})  # Incorpora dos usuarios nuevos al diccionario existente
#print(user_ids)  # Muestra user_ids con los cuatro usuarios ya cargados

# %%
#If we wanted to add 3 new rooms, we could use:
#sensors.update({"pantry": 22, "guest room": 25, "patio": 34})  # Agrega tres claves nuevas al diccionario en una sola instrucción
#print("After", sensors)  # Muestra sensors ya con las seis habitaciones

# %%
##Add multiple keys
#sensors = {"living room": 21, "kitchen": 23, "bedroom": 20}  # Redefine sensors con solo tres habitaciones
#print("Before", sensors)  # Muestra sensors antes de agregarle más claves

# %%
#animals_in_zoo = {"dinosaurs": 0}  # Primera asignación de la variable a un diccionario
#animals_in_zoo = {"dinosaurs": 0}  # Reasigna la variable a un diccionario idéntico al anterior
#animals_in_zoo = {"horses": 2}  # Reasigna la variable a un diccionario distinto, descartando por completo el anterior
#print(animals_in_zoo)  # Solo imprime {"horses": 2}, ya que es lo único que la variable conserva

# %%
#menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}  # Diccionario con productos y su precio
#print("Before: ", menu)  # Muestra el estado del menú antes de modificarlo
#menu["cheesecake"] = 8  # Como "cheesecake" no existe aún, se agrega como clave nueva con valor 8
#print("After", menu)  # Muestra el menú ya con la clave "cheesecake" incluida

# %%
#my_empty_dictionary = {}  # Crea un diccionario sin ningún par clave:valor
#print(my_empty_dictionary)  # Muestra en consola las llaves vacías {}

# %%
#children = {"von Trapp": ["Johannes", "Rosmarie", "Eleonore"], "Corleone": ["Sonny", "Fredo", "Michael"]}  # Diccionario donde cada apellido es clave y su valor es una lista de nombres
#print(children)  # Muestra en consola el diccionario children

# %%
#Verifiying an error:
# powers = {[1, 2, 4, 8, 16]: 2, [1, 3, 9, 27, 81]: 3}  # Provocaría TypeError: las listas son mutables y no pueden usarse como clave, solo como valor
# print(powers)  # Nunca llega a ejecutarse porque la línea anterior detiene el programa con el error

# %%
#sensors = {"living room": 21, "kitchen": 23, "bedroom": 20, "pantry": 22}  # Diccionario con la temperatura registrada en cada habitación
#num_cameras = {"backyard": 6,  "garage": 2, "driveway": 1}  # Diccionario con la cantidad de cámaras instaladas en cada zona

# %%
#print(sensors)  # Muestra en consola todo el contenido de sensors
#print(num_cameras)  # Muestra en consola todo el contenido de num_cameras

# %%
#translations = {"mountain": "orod", "bread": "bass", "friend": "mellon", "horse": "roch"}  # Diccionario que asocia cada palabra en inglés con su equivalente en el idioma inventado
#print(translations)  # Muestra en consola el diccionario translations

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "source": [
        "<center>\n",
        "<font size=\"5\", color=\"blue\"><b>Campos Electromagnéticos\n",
        "\n",
        "<img src=\"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbFx4fyFcQFIQSty0UhFGIUfun101AeOPdtBw2RvaSWzqjJqm9L37JAC88&s=10\" width=\"900\" height=\"200\">\n",
        "\n",
        "<center>\n",
        "<font size=\"5\", color=\"blue\"><b>Profesor Pedro Ignacio Deaza"
      ],
      "metadata": {
        "id": "exirMdw_u-vH"
      }
    },
    {
      "cell_type": "markdown",
      "source": [
        "<center>\n",
        "\n",
        "Nombres Apellidos codigo [correo](https://)\n",
        "\n",
        "Nombres Apellidos codigo [correo](https://)\n"
      ],
      "metadata": {
        "id": "iVoAEqGjY187"
      }
    },
    {
      "cell_type": "markdown",
      "source": [
        "$$\\vec{F_{e}}=\\frac{1}{4\\piɛ_{o}}\\frac{qq_{o}}{r^{2}}\\hat{r}$$\n",
        "\n",
        "$$\\vec{F_{g}}=-G\\frac{Mm}{r^{2}}\\hat{r}$$"
      ],
      "metadata": {
        "id": "hN-5hR-HZix9"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "import numpy as np\n",
        "import matplotlib.pyplot as plt\n",
        "import scipy.constants as sc"
      ],
      "metadata": {
        "id": "_xjdwpJsbme9"
      },
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "code",
      "execution_count": None,
      "metadata": {
        "id": "63w7gC1Gu0jW",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 594
        },
        "outputId": "b83b3584-c0fe-43c8-b765-30cbaa94bedf"
      },
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 1200x600 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ],
      "source": [
        "pi=sc.pi\n",
        "q=2\n",
        "qo=1\n",
        "r=np.arange(0.1,10,0.01)\n",
        "Eo=sc.epsilon_0\n",
        "plt.figure(figsize=(12, 6))\n",
        "for qo in range(1,5):\n",
        "  Fe=(1/4*pi*Eo)*(q*qo/r**2)\n",
        "  plt.plot(r,Fe)\n",
        "plt.title(\"Coulomb Law\", color=\"blue\", fontsize=\"28\")\n",
        "plt.xlabel(\"Distance r  (m)\", color=\"blue\", fontsize=\"20\")\n",
        "plt.ylabel(\"Electric Force  (n)\", color=\"blue\", fontsize=\"20\")\n",
        "plt.grid()\n",
        "plt.show()"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "from mpl_toolkits.mplot3d import axes3d\n",
        "import matplotlib.pyplot as plt\n",
        "from matplotlib import cm\n",
        "from numpy import *\n",
        "from pylab import*\n",
        "import math\n",
        "import time\n",
        "import scipy.constants as sc\n",
        "fig = plt.figure(figsize=(16,12))\n",
        "ax = fig.add_subplot(111, projection='3d')\n",
        "r = np.linspace(0.4,15,50)\n",
        "th = np.linspace(0,2*pi,90)\n",
        "[r, th] =meshgrid (r,th)\n",
        "x = r*cos(th)\n",
        "y = r*sin(th)\n",
        "Eo=sc.epsilon_0\n",
        "q=1\n",
        "z=(1/4*np.pi*Eo)*(q/r**2)\n",
        "ax.plot_wireframe(x, y, -z,  rstride=5, cstride=5)\n",
        "ax.set_xlabel(r\"Distance  r\", fontsize=16, color=\"red\")\n",
        "ax.set_ylabel(r\"Distance  r\", fontsize=16, color=\"red\")\n",
        "ax.set_zlabel(r'Gravitational Field', fontsize=16, color=\"red\",rotation=30)\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 961
        },
        "id": "x9kjB9J9mw6Z",
        "outputId": "238b3bfb-67f2-4def-f521-be6195fde99d"
      },
      "execution_count": None,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 1600x1200 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'markdown',
#    'source': ['<center>\n',
#     '<font size="5", color="blue"><b>Campos Electromagnéticos\n',
#     '\n',
#     '<img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbFx4fyFcQFIQSty0UhFGIUfun101AeOPdtBw2RvaSWzqjJqm9L37JAC88&s=10" width="900" height="200">\n',
#     '\n',
#     '<center>\n',
#     '<font size="5", color="blue"><b>Profesor Pedro Ignacio Deaza'],
#    'metadata': {'id': 'exirMdw_u-vH'}},
#   {'cell_type': 'markdown',
#    'source': ['<center>\n',
#     '\n',
#     'Nombres Apellidos codigo [correo](https://)\n',
#     '\n',
#     'Nombres Apellidos codigo [correo](https://)\n'],
#    'metadata': {'id': 'iVoAEqGjY187'}},
#   {'cell_type': 'markdown',
# ...
